# %%
import pandas as pd
import pycountry_convert as pc

# %%
df = pd.read_excel("education_data.xlsx")

# %% [markdown]
# ## Observe the data

# %%
df
# Out:
#          country  1970  1971  1972  1973  1974  1975   1976   1977   1978  \
# 0    Afghanistan  1.82  1.87  1.92  1.97  2.02  2.07   2.12   2.17   2.23
# 1        Albania  5.47  5.58  5.69  5.80  5.91  6.02   6.13   6.24   6.36
# 2        Algeria  2.77  2.86  2.95  3.04  3.14  3.25   3.35   3.46   3.58
# 3        Andorra  9.16  9.30  9.44  9.58  9.72  9.86  10.00  10.10  10.30
# 4         Angola  2.25  2.31  2.36  2.42  2.48  2.54   2.60   2.67   2.73
# ..           ...   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 182    Venezuela  5.00  5.10  5.21  5.31  5.42  5.53   5.64   5.75   5.86
# 183      Vietnam  4.50  4.60  4.69  4.79  4.89  4.99   5.10   5.20   5.31
# 184        Yemen  2.56  2.63  2.70  2.78  2.85  2.93   3.01   3.09   3.17
# 185       Zambia  3.78  3.87  3.95  4.03  4.11  4.19   4.28   4.36   4.45
# 186     Zimbabwe  5.00  5.11  5.22  5.33  5.43  5.55   5.66   5.77   5.89
#
#      ...   2006   2007   2008   2009   2010   2011   2012   2013   2014   2015
# ...

# %% [markdown]
# ## Get the shape of the data

# %%
df.shape
# Out:
# (187, 47)

# %%
df.head()
# Out:
#        country  1970  1971  1972  1973  1974  1975   1976   1977   1978  ...  \
# 0  Afghanistan  1.82  1.87  1.92  1.97  2.02  2.07   2.12   2.17   2.23  ...
# 1      Albania  5.47  5.58  5.69  5.80  5.91  6.02   6.13   6.24   6.36  ...
# 2      Algeria  2.77  2.86  2.95  3.04  3.14  3.25   3.35   3.46   3.58  ...
# 3      Andorra  9.16  9.30  9.44  9.58  9.72  9.86  10.00  10.10  10.30  ...
# 4       Angola  2.25  2.31  2.36  2.42  2.48  2.54   2.60   2.67   2.73  ...
#
#     2006   2007   2008   2009   2010   2011   2012   2013   2014   2015
# 0   4.33   4.43   4.53   4.63   4.73   4.84   4.94   5.05   5.16   5.27
# 1   9.89  10.00  10.20  10.30  10.40  10.60  10.70  10.90  11.00  11.20
# 2   8.13   8.28   8.42   8.57   8.71   8.85   8.99   9.14   9.28   9.42
# 3  13.90  14.10  14.20  14.30  14.40  14.50  14.60  14.70  14.80  14.90
# 4   5.10   5.21   5.32   5.43   5.55   5.66   5.78   5.90   6.02   6.14
#
# [5 rows x 47 columns]

# %% [markdown]
# ## Get column values

# %%
df.columns
# Out:
# Index(['country',      1970,      1971,      1972,      1973,      1974,
#             1975,      1976,      1977,      1978,      1979,      1980,
#             1981,      1982,      1983,      1984,      1985,      1986,
#             1987,      1988,      1989,      1990,      1991,      1992,
#             1993,      1994,      1995,      1996,      1997,      1998,
#             1999,      2000,      2001,      2002,      2003,      2004,
#             2005,      2006,      2007,      2008,      2009,      2010,
#             2011,      2012,      2013,      2014,      2015],
#       dtype='object')

# %% [markdown]
# ## Get index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=187, step=1)

# %% [markdown]
# ## Get row values

# %%
df.values
# Out:
# array([['Afghanistan', 1.82, 1.87, ..., 5.05, 5.16, 5.27],
#        ['Albania', 5.47, 5.58, ..., 10.9, 11.0, 11.2],
#        ['Algeria', 2.77, 2.86, ..., 9.14, 9.28, 9.42],
#        ...,
#        ['Yemen', 2.56, 2.63, ..., 7.82, 7.97, 8.11],
#        ['Zambia', 3.78, 3.87, ..., 8.03, 8.16, 8.29],
#        ['Zimbabwe', 5.0, 5.11, ..., 10.3, 10.4, 10.5]], dtype=object)

# %%
df
# Out:
#          country  1970  1971  1972  1973  1974  1975   1976   1977   1978  \
# 0    Afghanistan  1.82  1.87  1.92  1.97  2.02  2.07   2.12   2.17   2.23
# 1        Albania  5.47  5.58  5.69  5.80  5.91  6.02   6.13   6.24   6.36
# 2        Algeria  2.77  2.86  2.95  3.04  3.14  3.25   3.35   3.46   3.58
# 3        Andorra  9.16  9.30  9.44  9.58  9.72  9.86  10.00  10.10  10.30
# 4         Angola  2.25  2.31  2.36  2.42  2.48  2.54   2.60   2.67   2.73
# ..           ...   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 182    Venezuela  5.00  5.10  5.21  5.31  5.42  5.53   5.64   5.75   5.86
# 183      Vietnam  4.50  4.60  4.69  4.79  4.89  4.99   5.10   5.20   5.31
# 184        Yemen  2.56  2.63  2.70  2.78  2.85  2.93   3.01   3.09   3.17
# 185       Zambia  3.78  3.87  3.95  4.03  4.11  4.19   4.28   4.36   4.45
# 186     Zimbabwe  5.00  5.11  5.22  5.33  5.43  5.55   5.66   5.77   5.89
#
#      ...   2006   2007   2008   2009   2010   2011   2012   2013   2014   2015
# ...

# %% [markdown]
# ## Get individual columns

# %%
country = df["country"]

# %% [markdown]
# ## Get subset of the data

# %%
subset = df[["country",1970]]

# %%
subset.head()
# Out:
#        country  1970
# 0  Afghanistan  1.82
# 1      Albania  5.47
# 2      Algeria  2.77
# 3      Andorra  9.16
# 4       Angola  2.25

# %% [markdown]
# ## Simple operations on the columns

# %%
df["new_field"] = df[1970] + df[1971]

# %%
df["new_field_1"] = df[1970] * 2

# %%
df["new_field_1"]
# Out:
# 0       3.64
# 1      10.94
# 2       5.54
# 3      18.32
# 4       4.50
#        ...
# 182    10.00
# 183     9.00
# 184     5.12
# 185     7.56
# 186    10.00
# Name: new_field_1, Length: 187, dtype: float64

# %% [markdown]
# ## Deleting a column

# %%
df = df.drop("new_field" , axis = 1)

# %%
df.drop(0)
# Out:
#                  country  1970  1971  1972  1973  1974  1975   1976   1977  \
# 1                Albania  5.47  5.58  5.69  5.80  5.91  6.02   6.13   6.24
# 2                Algeria  2.77  2.86  2.95  3.04  3.14  3.25   3.35   3.46
# 3                Andorra  9.16  9.30  9.44  9.58  9.72  9.86  10.00  10.10
# 4                 Angola  2.25  2.31  2.36  2.42  2.48  2.54   2.60   2.67
# 5    Antigua and Barbuda  7.46  7.59  7.72  7.86  7.99  8.12   8.26   8.40
# ..                   ...   ...   ...   ...   ...   ...   ...    ...    ...
# 182            Venezuela  5.00  5.10  5.21  5.31  5.42  5.53   5.64   5.75
# 183              Vietnam  4.50  4.60  4.69  4.79  4.89  4.99   5.10   5.20
# 184                Yemen  2.56  2.63  2.70  2.78  2.85  2.93   3.01   3.09
# 185               Zambia  3.78  3.87  3.95  4.03  4.11  4.19   4.28   4.36
# 186             Zimbabwe  5.00  5.11  5.22  5.33  5.43  5.55   5.66   5.77
#
# ...

# %% [markdown]
# ## Reseting the index

# %%
df.reset_index(drop = True)
# Out:
#          country  1970  1971  1972  1973  1974  1975   1976   1977   1978  \
# 0    Afghanistan  1.82  1.87  1.92  1.97  2.02  2.07   2.12   2.17   2.23
# 1        Albania  5.47  5.58  5.69  5.80  5.91  6.02   6.13   6.24   6.36
# 2        Algeria  2.77  2.86  2.95  3.04  3.14  3.25   3.35   3.46   3.58
# 3        Andorra  9.16  9.30  9.44  9.58  9.72  9.86  10.00  10.10  10.30
# 4         Angola  2.25  2.31  2.36  2.42  2.48  2.54   2.60   2.67   2.73
# ..           ...   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 182    Venezuela  5.00  5.10  5.21  5.31  5.42  5.53   5.64   5.75   5.86
# 183      Vietnam  4.50  4.60  4.69  4.79  4.89  4.99   5.10   5.20   5.31
# 184        Yemen  2.56  2.63  2.70  2.78  2.85  2.93   3.01   3.09   3.17
# 185       Zambia  3.78  3.87  3.95  4.03  4.11  4.19   4.28   4.36   4.45
# 186     Zimbabwe  5.00  5.11  5.22  5.33  5.43  5.55   5.66   5.77   5.89
#
#      ...   2007   2008   2009   2010   2011   2012   2013   2014   2015  \
# ...

# %% [markdown]
# ## Rows based on values

# %%
df.loc[[0,1]]
# Out:
#        country  1970  1971  1972  1973  1974  1975  1976  1977  1978  ...  \
# 0  Afghanistan  1.82  1.87  1.92  1.97  2.02  2.07  2.12  2.17  2.23  ...
# 1      Albania  5.47  5.58  5.69  5.80  5.91  6.02  6.13  6.24  6.36  ...
#
#     2007   2008   2009   2010   2011   2012   2013   2014   2015  new_field_1
# 0   4.43   4.53   4.63   4.73   4.84   4.94   5.05   5.16   5.27         3.64
# 1  10.00  10.20  10.30  10.40  10.60  10.70  10.90  11.00  11.20        10.94
#
# [2 rows x 48 columns]

# %% [markdown]
# ## Rows based on index

# %%
df.iloc[[0,1]]
# Out:
#              1970  1971  1972  1973  1974  1975  1976  1977  1978  1979  ...  \
# country                                                                  ...
# Afghanistan  1.82  1.87  1.92  1.97  2.02  2.07  2.12  2.17  2.23  2.28  ...
# Albania      5.47  5.58  5.69  5.80  5.91  6.02  6.13  6.24  6.36  6.47  ...
#
#               2007   2008   2009   2010   2011   2012   2013   2014   2015  \
# country
# Afghanistan   4.43   4.53   4.63   4.73   4.84   4.94   5.05   5.16   5.27
# Albania      10.00  10.20  10.30  10.40  10.60  10.70  10.90  11.00  11.20
#
#              new_field_1
# country
# Afghanistan         3.64
# Albania            10.94
#
# [2 rows x 47 columns]

# %% [markdown]
# ## Set index to a particular column

# %%
df = df.set_index("country")

# %%
df.loc[['Afghanistan']]
# Out:
#              1970  1971  1972  1973  1974  1975  1976  1977  1978  1979  ...  \
# country                                                                  ...
# Afghanistan  1.82  1.87  1.92  1.97  2.02  2.07  2.12  2.17  2.23  2.28  ...
#
#              2007  2008  2009  2010  2011  2012  2013  2014  2015  new_field_1
# country
# Afghanistan  4.43  4.53  4.63  4.73  4.84  4.94  5.05  5.16  5.27         3.64
#
# [1 rows x 47 columns]

# %% [markdown]
# ## Using multiple conditions

# %%
df.loc[(df["country"] == 'Afghanistan') & (df[1970] == 1.82)]
# Out:
#        country  1970  1971  1972  1973  1974  1975  1976  1977  1978  ...  \
# 0  Afghanistan  1.82  1.87  1.92  1.97  2.02  2.07  2.12  2.17  2.23  ...
#
#    2006  2007  2008  2009  2010  2011  2012  2013  2014  2015
# 0  4.33  4.43  4.53  4.63  4.73  4.84  4.94  5.05  5.16  5.27
#
# [1 rows x 47 columns]

# %% [markdown]
# ## Group by

# %%
df.groupby(["country"]).mean()
# Out:
#              1970  1971  1972  1973  1974  1975   1976   1977   1978   1979  \
# country
# Afghanistan  1.82  1.87  1.92  1.97  2.02  2.07   2.12   2.17   2.23   2.28
# Albania      5.47  5.58  5.69  5.80  5.91  6.02   6.13   6.24   6.36   6.47
# Algeria      2.77  2.86  2.95  3.04  3.14  3.25   3.35   3.46   3.58   3.69
# Andorra      9.16  9.30  9.44  9.58  9.72  9.86  10.00  10.10  10.30  10.40
# Angola       2.25  2.31  2.36  2.42  2.48  2.54   2.60   2.67   2.73   2.80
# ...           ...   ...   ...   ...   ...   ...    ...    ...    ...    ...
# Venezuela    5.00  5.10  5.21  5.31  5.42  5.53   5.64   5.75   5.86   5.97
# Vietnam      4.50  4.60  4.69  4.79  4.89  4.99   5.10   5.20   5.31   5.41
# Yemen        2.56  2.63  2.70  2.78  2.85  2.93   3.01   3.09   3.17   3.26
# Zambia       3.78  3.87  3.95  4.03  4.11  4.19   4.28   4.36   4.45   4.53
# Zimbabwe     5.00  5.11  5.22  5.33  5.43  5.55   5.66   5.77   5.89   6.00
#
# ...

# %% [markdown]
# ## Using aggregate functions

# %%
import numpy as np
df.groupby(["country"]).agg(np.mean).reset_index()
# Out:
#          country  1970  1971  1972  1973  1974  1975   1976   1977   1978  \
# 0    Afghanistan  1.82  1.87  1.92  1.97  2.02  2.07   2.12   2.17   2.23
# 1        Albania  5.47  5.58  5.69  5.80  5.91  6.02   6.13   6.24   6.36
# 2        Algeria  2.77  2.86  2.95  3.04  3.14  3.25   3.35   3.46   3.58
# 3        Andorra  9.16  9.30  9.44  9.58  9.72  9.86  10.00  10.10  10.30
# 4         Angola  2.25  2.31  2.36  2.42  2.48  2.54   2.60   2.67   2.73
# ..           ...   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 182    Venezuela  5.00  5.10  5.21  5.31  5.42  5.53   5.64   5.75   5.86
# 183      Vietnam  4.50  4.60  4.69  4.79  4.89  4.99   5.10   5.20   5.31
# 184        Yemen  2.56  2.63  2.70  2.78  2.85  2.93   3.01   3.09   3.17
# 185       Zambia  3.78  3.87  3.95  4.03  4.11  4.19   4.28   4.36   4.45
# 186     Zimbabwe  5.00  5.11  5.22  5.33  5.43  5.55   5.66   5.77   5.89
#
#      ...   2006   2007   2008   2009   2010   2011   2012   2013   2014   2015
# ...

# %% [markdown]
# ## Applying UDF on coulmns

# %%
def add1(x):
    x = x + 1
    return x

# %%
df[1970].apply(add1)
# Out:
# 0       2.82
# 1       6.47
# 2       3.77
# 3      10.16
# 4       3.25
#        ...
# 182     6.00
# 183     5.50
# 184     3.56
# 185     4.78
# 186     6.00
# Name: 1970, Length: 187, dtype: float64

# %% [markdown]
# ## Applying UDF on a new column

# %%
def countrytocontinent(countryName):
    try:
        country_code = pc.country_name_to_country_alpha2(countryName, cn_name_format="default")
        continent_name = pc.country_alpha2_to_continent_code(country_code)
        return continent_name
    except:
        return None

# %%
df = df.assign(continent = df.country.map(countrytocontinent))

# %%
df.groupby(["continent"]).mean()
# Out:
#                1970      1971      1972      1973      1974      1975  \
# continent
# AF         2.965490  3.037647  3.109804  3.183529  3.258235  3.335882
# AS         5.405870  5.512391  5.617826  5.726304  5.836304  5.944783
# EU         6.950000  7.068000  7.186250  7.304500  7.423500  7.541750
# NA         5.625714  5.733333  5.841905  5.949524  6.064762  6.169524
# OC         6.001000  6.108000  6.215000  6.321000  6.428000  6.534000
# SA         5.186667  5.290833  5.394167  5.500000  5.606667  5.713333
#
#                1976      1977      1978      1979  ...       2006       2007  \
# continent                                          ...
# AF         3.414706  3.494706  3.575490  3.657843  ...   6.336275   6.448824
# AS         6.055652  6.168043  6.278913  6.390435  ...   9.674130   9.795870
# EU         7.659250  7.777500  7.896750  8.014500  ...  11.153750  11.283000
# NA         6.286190  6.394762  6.503810  6.622857  ...   9.811429   9.945714
# ...
